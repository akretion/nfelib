# %%
import os
import pandas as pd
from nfelib.nfe.bindings.v4_0 import nfe_v4_00

# Caminho das notas
PATH_XMLS = './documentos/nfe_janeiro/'

# %%
import os
import polars as pl
from concurrent.futures import ProcessPoolExecutor
from nfelib.nfe.bindings.v4_0 import nfe_v4_00

def extrair_xml(caminho_xml):
    try:
        nfe = nfe_v4_00.parse(caminho_xml)
        dados_da_nota = []
        destinatario = nfe.infNFe.dest
